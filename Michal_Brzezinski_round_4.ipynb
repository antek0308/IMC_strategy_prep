# %% [markdown]
# Imports

# %%
import matplotlib.pyplot as plt
import pandas as pd
from helpers import wrangle_backtest
from statsmodels.tsa.stattools import adfuller
import statsmodels.api as sm

# %% [markdown]
# Loading round 4 data

# %%
with open("data/round4.log", "r", encoding="utf-8") as f:
    content = f.readlines()

trades_df, activity_logs_df, sandbox_logs = wrangle_backtest(content)

# %% [markdown]
# List unique instruments from round 4

# %%
unique_instruments = trades_df['symbol'].unique()

print("Instruments available in round 4:")
for symbol in unique_instruments:
    print("-", symbol)
# Out:
# Instruments available in round 4:
# - COCONUT_COUPON
# - COCONUT

# %% [markdown]
# Coconut and coconut_coupon data

# %%
# COCONUT
coconut_df = trades_df[trades_df['symbol'] == 'COCONUT'].copy()
coconut_df['timestamp'] = pd.to_numeric(coconut_df['timestamp'], errors='coerce')
coconut_df = coconut_df.sort_values('timestamp')

print("=== COCONUT trades ===")
print(coconut_df)

# COCONUT_COUPON
coupon_df = trades_df[trades_df['symbol'] == 'COCONUT_COUPON'].copy()
coupon_df['timestamp'] = pd.to_numeric(coupon_df['timestamp'], errors='coerce')
coupon_df = coupon_df.sort_values('timestamp')

print("\n=== COCONUT_COUPON trades ===")
print(coupon_df)
# Out:
# === COCONUT trades ===
#       timestamp       buyer      seller   symbol   currency  price  quantity
# 13         5200      Vinnie      Vinnie  COCONUT  SEASHELLS   9997         8
# 19         9300         Raj  SUBMISSION  COCONUT  SEASHELLS  10005         6
# 23        10900      Vinnie      Vinnie  COCONUT  SEASHELLS  10007        10
# 24        12500  SUBMISSION         Raj  COCONUT  SEASHELLS  10003         7
# 25        12500      Vinnie         Raj  COCONUT  SEASHELLS  10003         3
# ...         ...         ...         ...      ...        ...    ...       ...
# 5178    2994900      Vinnie      Vinnie  COCONUT  SEASHELLS   9885         9
# 5179    2995500      Vinnie      Vinnie  COCONUT  SEASHELLS   9887         8
# 5181    2997100      Vinnie      Vinnie  COCONUT  SEASHELLS   9885         9
# 5182    2997200      Vinnie      Vinnie  COCONUT  SEASHELLS   9883         8
# 5183    2998600      Vinnie         Raj  COCONUT  SEASHELLS   9887         5
#
# [1987 rows x 7 columns]
#
# === COCONUT_COUPON trades ===
#       timestamp      buyer     seller          symbol   currency  price  \
# 0           800  Valentina  Valentina  COCONUT_COUPON  SEASHELLS    636
# 1           900  Valentina     Vinnie  COCONUT_COUPON  SEASHELLS    634
# 2          1100  Valentina       Ruby  COCONUT_COUPON  SEASHELLS    635
# 3          1900  Valentina     Vinnie  COCONUT_COUPON  SEASHELLS    635
# 4          2000  Valentina     Vinnie  COCONUT_COUPON  SEASHELLS    637
# ...         ...        ...        ...             ...        ...    ...
# 5170    2992300  Valentina  Valentina  COCONUT_COUPON  SEASHELLS    575
# 5171    2992600  Valentina       Ruby  COCONUT_COUPON  SEASHELLS    574
# 5172    2992900  Valentina     Vinnie  COCONUT_COUPON  SEASHELLS    577
# 5180    2996200  Valentina     Vinnie  COCONUT_COUPON  SEASHELLS    585
# 5184    2999800  Valentina    Rhianna  COCONUT_COUPON  SEASHELLS    575
#
#       quantity
# 0            5
# 1           17
# 2           17
# 3           16
# 4           14
# ...        ...
# 5170         6
# 5171        14
# 5172        14
# 5180        14
# 5184        14
#
# [3198 rows x 7 columns]

# %% [markdown]
# Plotting COCONUT and COCONUT_COUPON price

# %%
# COCONUT
instrument = 'COCONUT'
instrument_df = trades_df[trades_df['symbol'] == instrument].copy()
instrument_df['timestamp'] = pd.to_numeric(instrument_df['timestamp'], errors='coerce')
instrument_df = instrument_df.sort_values('timestamp')

plt.figure(figsize=(10, 5))
plt.plot(instrument_df['timestamp'], instrument_df['price'], marker='o')
plt.title(f"Price of {instrument} over time (Round 4)")
plt.xlabel("Timestamp")
plt.ylabel("Price")
plt.grid(True)
plt.tight_layout()
plt.show()

# COCONUT_COUPON
instrument = 'COCONUT_COUPON'
instrument_df = trades_df[trades_df['symbol'] == instrument].copy()
instrument_df['timestamp'] = pd.to_numeric(instrument_df['timestamp'], errors='coerce')
instrument_df = instrument_df.sort_values('timestamp')

plt.figure(figsize=(10, 5))
plt.plot(instrument_df['timestamp'], instrument_df['price'], marker='o', color='orange')
plt.title(f"Price of {instrument} over time (Round 4)")
plt.xlabel("Timestamp")
plt.ylabel("Price")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Conclusions:
#
# COCONUT_COUPON shows greater relative price swings compared to COCONUT.
#
# This makes sense if COUPON is an option, options are generally more sensitive to changes in the underlying.

# %% [markdown]
# Correlation analysis

# %%
merged = pd.merge_asof(
    coconut_df.sort_values("timestamp"),
    coupon_df.sort_values("timestamp"),
    on="timestamp",
    direction="nearest",
    suffixes=("_coconut", "_coupon")
)

correlation = merged["price_coconut"].corr(merged["price_coupon"])
print(f"Correlation: {correlation:.4f}")
# Out:
# Correlation: 0.9575

# %% [markdown]
# Conclusions:
#
# A high value close to +1 confirms that COCONUT_COUPON follows the base asset closely.

# %% [markdown]
# Linear regression (OLS)
#
# COCONUT_COUPON ~ a * COCONUT + b

# %%
X = merged["price_coconut"]
y = merged["price_coupon"]
X = sm.add_constant(X)

model = sm.OLS(y, X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           price_coupon   R-squared:                       0.917
# Model:                            OLS   Adj. R-squared:                  0.917
# Method:                 Least Squares   F-statistic:                 2.186e+04
# Date:                Mon, 02 Jun 2025   Prob (F-statistic):               0.00
# Time:                        15:48:19   Log-Likelihood:                -7989.6
# No. Observations:                1987   AIC:                         1.598e+04
# Df Residuals:                    1985   BIC:                         1.599e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const         -4398.5021     34.045   -129.197      0.000   -4465.269   -4331.735
# price_coconut     0.5033      0.003    147.843      0.000       0.497       0.510
# ==============================================================================
# Omnibus:                       17.806   Durbin-Watson:                   0.093
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               12.688
# Skew:                           0.072   Prob(JB):                      0.00176
# Kurtosis:                       2.636   Cond. No.                     1.12e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.12e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# Conclusions:
#
# 1. R-squared = 0.917
# 91.7% of the variance in COCONUT_COUPON is explained by COCONUT.
# This is very high and confirms a strong linear relationship as COCONUT_COUPON behaves like a derivative of COCONUT.
#
# 2. Slope (coefficient for price_coconut) = 0.5033
# Interpretation: for every 1-point change in the price of COCONUT, the COCONUT_COUPON price moves by ~0.50 points.
# This resembles the delta of a call option, which often starts near 0.5.

# %%
# Stationarity test for COCONUT and COCONUT_COUPON
for label, series in [("COCONUT", coconut_df["price"]), ("COCONUT_COUPON", coupon_df["price"])]:
    result = adfuller(series.dropna())
    print(f"{label} ADF Statistic: {result[0]:.4f}, p-value: {result[1]:.4f}")
# Out:
# COCONUT ADF Statistic: -0.5439, p-value: 0.8832
# COCONUT_COUPON ADF Statistic: -1.8734, p-value: 0.3447

# %% [markdown]
# Conclusions:
#
# Stationarity Test Results
#
# The Augmented Dickey-Fuller (ADF) test was used to check if the price series for COCONUT and COCONUT_COUPON are stationary.
#
# Both p-values are much greater than 0.05, so we fail to reject the null hypothesis. This indicates that both price series are non-stationary, meaning their statistical properties (such as mean and variance) change over time.

# %%
import numpy as np

# %%
# Rolling volatility
coconut_df["rolling_std"] = coconut_df["price"].rolling(window=21).std() * np.sqrt(252)
coupon_df["rolling_std"] = coupon_df["price"].rolling(window=21).std() * np.sqrt(252)

plt.figure(figsize=(10, 5))
plt.plot(coconut_df["timestamp"], coconut_df["rolling_std"], label="COCONUT")
plt.plot(coupon_df["timestamp"], coupon_df["rolling_std"], label="COCONUT_COUPON")
plt.title("Rolling 50-period Volatility")
plt.xlabel("Timestamp")
plt.ylabel("Rolling Std Dev")
plt.legend()
plt.show()

# %% [markdown]
# Conclusions:
#
# The plot above shows the rolling monthly standard deviation (volatility) for both COCONUT and COCONUT_COUPON over time.
#
# Both instruments experience periods of increased and decreased volatility, with noticeable spikes throughout the round.
# COCONUT_COUPON generally exhibits higher and more frequent volatility spikes compared to COCONUT.
